# %% [markdown]
# **PROGRAMA ONE G9 - alura + Oracle**
#
# **Tech Foundation - CIENCIA DE DATOS**
#
# **DESAFÍO 1: ALURA STORE**

# %% [markdown]
# **Alumno: Esteban David Galdames**

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# # 1. Análisis de facturación

# %% [markdown]
# **Ingreso total por cada tienda**
#
# En este primer análisis, debes calcular el ingreso total de cada tienda sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %% [markdown]
# ## **Ingreso total de la tienda 1**

# %%
# Extraer los precios de la tienda 1
tienda1_precios = tienda['Precio']

# %%
# Visualizo los precios de la tienda 1
tienda1_precios
# Out:
# 0        164300.0
# 1        192300.0
# 2        209600.0
# 3        757500.0
# 4        335200.0
#           ...
# 2354    1284400.0
# 2355     282800.0
# 2356     122900.0
# 2357     691300.0
# 2358     195000.0
# Name: Precio, Length: 2359, dtype: float64

# %%
# Calculo la suma de las ventas
# Aplico el método sum
tienda1_ventas = tienda1_precios.sum()

# %%
# Visualizo mi resultado
tienda1_ventas
# Out:
# np.float64(1150880400.0)

# %%
# O bien
tienda1_ventas = tienda['Precio'].sum()
tienda1_ventas
# Out:
# np.float64(1150880400.0)

# %%
# Verifico mi salida
type(tienda1_ventas)
# Out:
# numpy.float64

# %%
tienda.Precio.sum()
# Out:
# np.float64(1150880400.0)

# %%
# Selecciono la columna 'Precio' del dataframe tienda y utilizo el método sum()
ventas_tienda1 = tienda['Precio'].sum()

# %%
# Obtengo el ingreso total de la tienda 1
print(f'El ingreso total de la tienda 1 es: {ventas_tienda1}')
# Out:
# El ingreso total de la tienda 1 es: 1150880400.0

# %% [markdown]
# ## **Ingreso total de la tienda 2**

# %%
# Selecciono la columna 'Precio' del dataframe tienda2 y utilizo el método sum()
ventas_tienda2 = tienda2['Precio'].sum()

# %%
# Obtengo el ingreso total de la tienda 2
print(f'El ingreso total de la tienda 2 es: {ventas_tienda2}')
# Out:
# El ingreso total de la tienda 2 es: 1116343500.0

# %% [markdown]
# ## **Ingreso total de la tienda 3**

# %%
# Selecciono la columna 'Precio' del dataframe tienda3 y utilizo el método sum()
ventas_tienda3 = tienda3['Precio'].sum()

# %%
# Obtengo el ingreso total de la tienda 3
print(f'El ingreso total de la tienda 3 es: {ventas_tienda3}')
# Out:
# El ingreso total de la tienda 3 es: 1098019600.0

# %% [markdown]
# ## **Ingreso total de la tienda 4**

# %%
# Selecciono la columna 'Precio' del dataframe tienda4 y utilizo el método sum()
ventas_tienda4 = tienda4['Precio'].sum()

# %%
# Obtengo el ingreso total de la tienda 4
print(f'El ingreso total de la tienda 4 es: {ventas_tienda4}')
# Out:
# El ingreso total de la tienda 4 es: 1038375700.0

# %% [markdown]
# ## **Ingreso total de las tiendas**

# %%
# El total de ingresos será la suma de las ventas de las 4 tiendas
total_ingresos = ventas_tienda1 + ventas_tienda2 + ventas_tienda3 + ventas_tienda4

# %%
# Obtengo el ingreso total
print(f'El ingreso total de las 4 tiendas es: {total_ingresos}')
# Out:
# El ingreso total de las 4 tiendas es: 4403619200.0

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este análisis debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %% [markdown]
# ## **Ventas por categoría tienda 1**

# %%
# CANTIDAD DE VENTAS POR CATEGORÍA
# Agrupo los registros según la columna 'Categoría del Producto'
# Utilizo el método value_counts()
tienda1_categorias = tienda['Categoría del Producto'].value_counts()

# %%
# Visualizo la cantidad de productos vendidos por categoría en la tienda 1
tienda1_categorias
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
# INGRESOS POR CATEGORÍA
# Agrupo los registros por categoría mediante el método groupby()
# Debo especificar la columna 'Precio' y aplicar el método sum()
tienda1_categorias_ingresos = tienda.groupby('Categoría del Producto')['Precio'].sum()

# %%
# Visualizo los ingresos totales por categoría de la tienda 1
tienda1_categorias_ingresos
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64

# %%
# Observo que el tipo de dato obtenido es una serie pandas
# Observo que la serie está ordenada alfabéticamente según la categoría del producto
# Para una mejor visualización ordeno las categorías en orden ascendente utilizando ascending=False
tienda1_categorias_ingresos.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Electrónicos               429493500.0
# Electrodomésticos          363685200.0
# Muebles                    187633700.0
# Instrumentos musicales      91299000.0
# Deportes y diversión        39290000.0
# Juguetes                    17995700.0
# Artículos para el hogar     12698400.0
# Libros                       8784900.0
# Name: Precio, dtype: float64

# %%
# Guardo los cambios en mi variable o bien ordeno directamente al crearla
tienda1_categorias_ingresos = tienda.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)

# %%
# También puedo obtener un dataframe pandas en lugar de una serie pandas
# En este caso el método sort values requiere que se indique la columna por la cual se ordena
tienda1_categorias_ingresos = tienda.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio', ascending=False)

# %%
# Visualizo el dataframe pandas de ingresos por categorías
tienda1_categorias_ingresos
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             429493500.0
# Electrodomésticos        363685200.0
# Muebles                  187633700.0
# Instrumentos musicales    91299000.0
# Deportes y diversión      39290000.0
# Juguetes                  17995700.0
# Artículos para el hogar   12698400.0
# Libros                     8784900.0

# %% [markdown]
# ## **Ventas por categoría tienda 2**

# %%
# CANTIDAD DE VENTAS POR CATEGORÍA
# Agrupo los registros según la columna 'Categoría del Producto'
# Utilizo el método value_counts()
tienda2_categorias = tienda2['Categoría del Producto'].value_counts()

# %%
# Visualizo la cantidad de productos vendidos por categoría en la tienda 2
tienda2_categorias
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
# INGRESOS POR CATEGORÍA
# Agrupo los registros por categoría mediante el método groupby()
# Debo especificar la columna 'Precio' y aplicar el método sum()
tienda2_categorias_ingresos = tienda2.groupby('Categoría del Producto')['Precio'].sum()

# %%
# Visualizo los ingresos totales por categoría de la tienda 2
tienda2_categorias_ingresos
# Out:
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
# Name: Precio, dtype: float64

# %%
# El dataframe pandas ordenado para una mejor visualización
tienda2_categorias_ingresos = tienda2.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio', ascending=False)

# %%
# Visualizo el dataframe obtenido
tienda2_categorias_ingresos
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             410831100.0
# Electrodomésticos        348567800.0
# Muebles                  176426300.0
# Instrumentos musicales   104990300.0
# Deportes y diversión      34744500.0
# Juguetes                  15945400.0
# Artículos para el hogar   14746900.0
# Libros                    10091200.0

# %% [markdown]
# ## **Ventas por categoría tienda 3**

# %%
# CANTIDAD DE VENTAS POR CATEGORÍA
# Agrupo los registros según la columna 'Categoría del Producto'
# Utilizo el método value_counts()
tienda3_categorias = tienda3['Categoría del Producto'].value_counts()

# %%
# Visualizo la cantidad de productos vendidos por categoría en la tienda 3
tienda3_categorias
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
# INGRESOS POR CATEGORÍA
# Agrupo los registros por categoría mediante el método groupby()
# Debo especificar la columna 'Precio' y aplicar el método sum()
tienda3_categorias_ingresos = tienda3.groupby('Categoría del Producto')['Precio'].sum()

# %%
# Visualizo los ingresos totales por categoría de la tienda 3
tienda3_categorias_ingresos
# Out:
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# Electrodomésticos          329237900.0
# Electrónicos               410775800.0
# Instrumentos musicales      77380900.0
# Juguetes                    19401100.0
# Libros                       9498700.0
# Muebles                    201072100.0
# Name: Precio, dtype: float64

# %%
# El dataframe pandas ordenado para una mejor visualización
tienda3_categorias_ingresos = tienda3.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio', ascending=False)

# %%
# Visualizo el dataframe obtenido
tienda3_categorias_ingresos
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             410775800.0
# Electrodomésticos        329237900.0
# Muebles                  201072100.0
# Instrumentos musicales    77380900.0
# Deportes y diversión      35593100.0
# Juguetes                  19401100.0
# Artículos para el hogar   15060000.0
# Libros                     9498700.0

# %% [markdown]
# ## **Ventas por categoría tienda 4**

# %%
# CANTIDAD DE VENTAS POR CATEGORÍA
# Agrupo los registros según la columna 'Categoría del Producto'
# Utilizo el método value_counts()
tienda4_categorias = tienda4['Categoría del Producto'].value_counts()

# %%
# Visualizo la cantidad de productos vendidos por categoría en la tienda
tienda4_categorias
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
# INGRESOS POR CATEGORÍA
# Agrupo los registros por categoría mediante el método groupby()
# Debo especificar la columna 'Precio' y aplicar el método sum()
tienda4_categorias_ingresos = tienda4.groupby('Categoría del Producto')['Precio'].sum()

# %%
# Visualizo los ingresos totales por categoría de la tienda 4
tienda4_categorias_ingresos
# Out:
# Categoría del Producto
# Artículos para el hogar     15074500.0
# Deportes y diversión        33350100.0
# Electrodomésticos          283260200.0
# Electrónicos               409476100.0
# Instrumentos musicales      75102400.0
# Juguetes                    20262200.0
# Libros                       9321300.0
# Muebles                    192528900.0
# Name: Precio, dtype: float64

# %%
# El dataframe pandas ordenado para una mejor visualización
tienda4_categorias_ingresos = tienda4.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio', ascending=False)

# %%
# Visualizo el dataframe obtenido
tienda4_categorias_ingresos
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             409476100.0
# Electrodomésticos        283260200.0
# Muebles                  192528900.0
# Instrumentos musicales    75102400.0
# Deportes y diversión      33350100.0
# Juguetes                  20262200.0
# Artículos para el hogar   15074500.0
# Libros                     9321300.0

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# **Valoración media por tienda**
#
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
# Obtengo el promedio de las calificaciones de la tienda 1 aplicando el método mean()
tienda1_calificacion = tienda['Calificación'].mean()

# %%
# Visualizo la calificación media de la tienda 1
tienda1_calificacion
# Out:
# np.float64(3.976685036032217)

# %%
# Obtengo el promedio de las calificaciones de la tienda 2 aplicando el método mean()
tienda2_calificacion = tienda2['Calificación'].mean()

# %%
# Visualizo la calificación media de la tienda 2
tienda2_calificacion
# Out:
# np.float64(4.037303942348453)

# %%
# Obtengo el promedio de las calificaciones de la tienda 3 aplicando el método mean()
tienda3_calificacion = tienda3['Calificación'].mean()

# %%
# Visualizo la calificación media de la tienda 3
tienda3_calificacion
# Out:
# np.float64(4.048325561678677)

# %%
# Obtengo el promedio de las calificaciones de la tienda 4 aplicando el método mean()
tienda4_calificacion = tienda4['Calificación'].mean()

# %%
# Visualizo la calificación media de la tienda 4
tienda4_calificacion
# Out:
# np.float64(3.9957591178965224)

# %%
# Imprimo las calificaciones obtenidas
print('El promedio de las calificaciones del cliente obtenidas son:')
print(f'Tienda 1: {tienda1_calificacion}')
print(f'Tienda 2: {tienda2_calificacion}')
print(f'Tienda 3: {tienda3_calificacion}')
print(f'Tienda 4: {tienda4_calificacion}')
# Out:
# El promedio de las calificaciones del cliente obtenidas son:
# Tienda 1: 3.976685036032217
# Tienda 2: 4.037303942348453
# Tienda 3: 4.048325561678677
# Tienda 4: 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %% [markdown]
# ## **Productos más vendidos en la tienda 1**

# %%
# Contabilizo los productos vendidos utilizando el método value_counts
tienda['Producto'].value_counts()
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %%
# Obtengo los ingresos totales por producto ordenados de mayor a menor
tienda.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
# Out:
# Producto
# TV LED UHD 4K                  142150200.0
# Refrigerador                   112143300.0
# Iphone 15                       97902200.0
# Smart TV                        67452100.0
# Lavadora de ropa                65783600.0
# Lavavajillas                    62054900.0
# Secadora de ropa                59062400.0
# Tablet ABXY                     47639800.0
# Batería                         37693900.0
# Guitarra eléctrica              37292200.0
# Microondas                      34761500.0
# Celular ABXY                    32651000.0
# Sofá reclinable                 31379400.0
# Cama king                       31176600.0
# Estufa                          29879500.0
# Armario                         29462300.0
# Bicicleta                       27444600.0
# Cama box                        22094700.0
# Silla de oficina                17667300.0
# Impresora                       16413300.0
# Mesa de noche                   15679600.0
# ...

# %%
# Almaceno el resultado en un dataframe pandas de ingresos por producto
tienda1_productos_ingresos = tienda.groupby('Producto')[['Precio']].sum().sort_values('Precio', ascending=False)

# %%
# Visualizo los 5 productos que generaron más ingresos
tienda1_productos_ingresos.head()
# Out:
#                        Precio
# Producto
# TV LED UHD 4K     142150200.0
# Refrigerador      112143300.0
# Iphone 15          97902200.0
# Smart TV           67452100.0
# Lavadora de ropa   65783600.0

# %%
# Visualizo los 5 productos que generaron menos ingresos
tienda1_productos_ingresos.tail()
# Out:
#                        Precio
# Producto
# Ajedrez de madera   1430600.0
# Set de vasos        1359100.0
# Cubo mágico 8x8      696900.0
# Dinosaurio Rex       688900.0
# Cuerda para saltar   652800.0

# %% [markdown]
# ## **Productos más vendidos en la tienda 2**

# %%
# Contabilizo los productos vendidos utilizando el método value_counts
tienda2['Producto'].value_counts()
# Out:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# ...

# %%
# Obtengo los ingresos totales por producto ordenados de mayor a menor
tienda2.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
# Out:
# Producto
# Iphone 15                      113225800.0
# TV LED UHD 4K                  103375000.0
# Refrigerador                    97632500.0
# Lavadora de ropa                66762300.0
# Smart TV                        61142000.0
# Secadora de ropa                59115100.0
# Lavavajillas                    58767500.0
# Tablet ABXY                     56209800.0
# Batería                         46175300.0
# Celular ABXY                    41668900.0
# Guitarra eléctrica              36441500.0
# Microondas                      36192000.0
# Estufa                          30098400.0
# Sofá reclinable                 29489200.0
# Cama king                       28213700.0
# Armario                         26174900.0
# Cama box                        24357100.0
# Bicicleta                       22958300.0
# Guitarra acústica               18648400.0
# Silla de oficina                18530000.0
# Kit de bancas                   12604800.0
# ...

# %%
# Almaceno el resultado en un dataframe pandas de ingresos por producto
tienda2_productos_ingresos = tienda2.groupby('Producto')[['Precio']].sum().sort_values('Precio', ascending=False)

# %%
# Visualizo los 5 productos que generaron más ingresos
tienda2_productos_ingresos.head()
# Out:
#                        Precio
# Producto
# Iphone 15         113225800.0
# TV LED UHD 4K     103375000.0
# Refrigerador       97632500.0
# Lavadora de ropa   66762300.0
# Smart TV           61142000.0

# %%
# Visualizo los 5 productos que generaron menos ingresos
tienda2_productos_ingresos.tail()
# Out:
#                        Precio
# Producto
# Set de vasos        1542600.0
# Ajedrez de madera   1287700.0
# Cuerda para saltar   856900.0
# Dinosaurio Rex       770300.0
# Cubo mágico 8x8      643600.0

# %% [markdown]
# ## **Productos más vendidos en la tienda 3**

# %%
# Contabilizo los productos vendidos utilizando el método value_counts
tienda3['Producto'].value_counts()
# Out:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# ...

# %%
# Obtengo los ingresos totales por producto ordenados de mayor a menor
tienda3.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
# Out:
# Producto
# Refrigerador                   99889700.0
# TV LED UHD 4K                  96669100.0
# Iphone 15                      93225700.0
# Smart TV                       78837300.0
# Lavavajillas                   64364800.0
# Tablet ABXY                    58440100.0
# Lavadora de ropa               57459100.0
# Secadora de ropa               49798300.0
# Celular ABXY                   43419600.0
# Cama king                      38834700.0
# Estufa                         38572400.0
# Sofá reclinable                30319800.0
# Guitarra eléctrica             29848000.0
# Batería                        29369200.0
# Cama box                       24699700.0
# Bicicleta                      24654800.0
# Armario                        24187200.0
# Microondas                     19153600.0
# Silla de oficina               18376300.0
# Kit de bancas                  16699800.0
# Mesa de noche                  15365500.0
# Guitarra acústica              14918600.0
# ...

# %%
# Almaceno el resultado en un dataframe pandas de ingresos por producto
tienda3_productos_ingresos = tienda3.groupby('Producto')[['Precio']].sum().sort_values('Precio', ascending=False)

# %%
# Visualizo los 5 productos que generaron más ingresos
tienda3_productos_ingresos.head()
# Out:
#                    Precio
# Producto
# Refrigerador   99889700.0
# TV LED UHD 4K  96669100.0
# Iphone 15      93225700.0
# Smart TV       78837300.0
# Lavavajillas   64364800.0

# %%
# Visualizo los 5 productos que generaron menos ingresos
tienda3_productos_ingresos.tail()
# Out:
#                             Precio
# Producto
# Bloques de construcción  1237200.0
# Set de vasos             1210700.0
# Cuerda para saltar        853800.0
# Dinosaurio Rex            795600.0
# Cubo mágico 8x8           640400.0

# %% [markdown]
# ## **Productos más vendidos en la tienda 4**

# %%
# Contabilizo los productos vendidos utilizando el método value_counts
tienda4['Producto'].value_counts()
# Out:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# ...

# %%
# Obtengo los ingresos totales por producto ordenados de mayor a menor
tienda4.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
# Out:
# Producto
# Iphone 15                      96697500.0
# TV LED UHD 4K                  90295300.0
# Smart TV                       82790400.0
# Refrigerador                   75271900.0
# Tablet ABXY                    56723100.0
# Lavavajillas                   55349300.0
# Lavadora de ropa               52463600.0
# Secadora de ropa               42262200.0
# Celular ABXY                   40171600.0
# Cama king                      37555400.0
# Batería                        34567900.0
# Cama box                       32946300.0
# Estufa                         32320800.0
# Sofá reclinable                32090700.0
# Guitarra eléctrica             25823100.0
# Microondas                     25592400.0
# Bicicleta                      21429800.0
# Armario                        16421400.0
# Impresora                      15210000.0
# Mesa de noche                  15144100.0
# Silla de oficina               14525400.0
# Mesa de comedor                13320600.0
# ...

# %%
# Almaceno el resultado en un dataframe pandas de ingresos por producto
tienda4_productos_ingresos = tienda4.groupby('Producto')[['Precio']].sum().sort_values('Precio', ascending=False)

# %%
# Visualizo los 5 productos que generaron más ingresos
tienda4_productos_ingresos.head()
# Out:
#                    Precio
# Producto
# Iphone 15      96697500.0
# TV LED UHD 4K  90295300.0
# Smart TV       82790400.0
# Refrigerador   75271900.0
# Tablet ABXY    56723100.0

# %%
# Visualizo los 5 productos que generaron menos ingresos
tienda4_productos_ingresos.tail()
# Out:
#                        Precio
# Producto
# Set de vasos        1471800.0
# Ajedrez de madera   1075500.0
# Dinosaurio Rex       858100.0
# Cubo mágico 8x8      748400.0
# Cuerda para saltar   704800.0

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# **Valor del envío promedio por tienda**
#
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %% [markdown]
# ## **Valor promedio del envío de la tienda 1**

# %%
# Calculo el promedio de los valores de la columna 'Costo de envío' de la tienda 1
tienda1_envio = tienda['Costo de envío'].mean()

# %%
# Visualizo el valor promedio del envío de la tienda 1
tienda1_envio
# Out:
# np.float64(26018.60958033065)

# %%
print(f'El valor promedio del envío de la tienda 1 es: {tienda1_envio}')
# Out:
# El valor promedio del envío de la tienda 1 es: 26018.60958033065

# %% [markdown]
# ## **Valor promedio del envío de la tienda 2**

# %%
# Calculo el promedio de los valores de la columna 'Costo de envío' de la tienda 2
tienda2_envio = tienda2['Costo de envío'].mean()

# %%
# Visualizo el valor promedio del envío de la tienda 2
tienda2_envio
# Out:
# np.float64(25216.235693090293)

# %%
print(f'El valor promedio del envío de la tienda 2 es: {tienda2_envio}')
# Out:
# El valor promedio del envío de la tienda 2 es: 25216.235693090293

# %% [markdown]
# ## **Valor promedio del envío de la tienda 3**

# %%
# Calculo el promedio de los valores de la columna 'Costo de envío' de la tienda 3
tienda3_envio = tienda3['Costo de envío'].mean()

# %%
# Visualizo el valor promedio del envío de la tienda 3
tienda3_envio
# Out:
# np.float64(24805.680373039424)

# %%
print(f'El valor promedio del envío de la tienda 3 es: {tienda3_envio}')
# Out:
# El valor promedio del envío de la tienda 3 es: 24805.680373039424

# %% [markdown]
# ## **Valor promedio del envío de la tienda 4**

# %%
# Calculo el promedio de los valores de la columna 'Costo de envío' de la tienda 4
tienda4_envio = tienda4['Costo de envío'].mean()

# %%
# Visualizo el valor promedio del envío de la tienda 4
tienda4_envio
# Out:
# np.float64(23459.457167090754)

# %%
print(f'El valor promedio del envío de la tienda 4 es: {tienda4_envio}')
# Out:
# El valor promedio del envío de la tienda 4 es: 23459.457167090754

# %% [markdown]
# # **VISUALIZACIÓN**

# %% [markdown]
# ## **COMPARATIVA DE INGRESOS POR TIENDA**

# %%
# Genero un dataframe comparativo de ingresos totales de las 4 tiendas
ingresos_por_tienda = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Ingresos': [ventas_tienda1, ventas_tienda2, ventas_tienda3, ventas_tienda4]
})

# %%
# Visualizo el dataframe comparativo de ingresos totales
ingresos_por_tienda
# Out:
#      Tienda      Ingresos
# 0  Tienda 1  1.150880e+09
# 1  Tienda 2  1.116344e+09
# 2  Tienda 3  1.098020e+09
# 3  Tienda 4  1.038376e+09

# %%
# Elimino los índices del dataframe
# ingresos_por_tienda.reset_index(drop=True, inplace=True)
# ingresos_por_tienda.set_index('Tienda', inplace=True)
ingresos_por_tienda.set_index('Tienda', inplace=True)

# %%
ingresos_por_tienda
# Out:
#               Ingresos
# Tienda
# Tienda 1  1.150880e+09
# Tienda 2  1.116344e+09
# Tienda 3  1.098020e+09
# Tienda 4  1.038376e+09

# %%
# Genero un gráfico utilizando pandas
ingresos_por_tienda.plot(kind='bar', xlabel='Tienda', ylabel='Ingresos', title='Ingresos por Tienda', figsize=(12, 8), color='powderblue', legend=False, rot=False)
# Out:
# <Axes: title={'center': 'Ingresos por Tienda'}, xlabel='Tienda', ylabel='Ingresos'>

# %% [markdown]
# **CONFORMACIÓN DEL INGRESO TOTAL:**
#
# Comparativa de la importancia de cada tienda en el ingreso total del señor Juan.
#
# Este es un enfoque distinto utilizando los mismos valores, ahora como parte de un todo.

# %%
ingresos_por_tienda.plot(kind='pie', title='Ingresos por Tienda', figsize=(12, 8),
                         legend=False, autopct='%1.1f%%', pctdistance=0.85, labeldistance=1.1, subplots=True, ylabel='')
# Out:
# array([<Axes: >], dtype=object)

# %% [markdown]
# ## **COMPARATIVA DE CALIFICACIÓN DEL CLIENTE POR TIENDA**

# %%
# Genero un dataframe pandas con las calificaciones de las cuatro tiendas
calificaciones_por_tienda = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Calificación': [tienda1_calificacion, tienda2_calificacion, tienda3_calificacion, tienda4_calificacion]
})

# %%
# Visualizo el dataframe
calificaciones_por_tienda
# Out:
#      Tienda  Calificación
# 0  Tienda 1      3.976685
# 1  Tienda 2      4.037304
# 2  Tienda 3      4.048326
# 3  Tienda 4      3.995759

# %%
# Formateo el dataframe colocando la Tienda como índice
calificaciones_por_tienda.set_index('Tienda', inplace=True)

# %%
# Visualizo mi dataframe de calificaciones por tienda
calificaciones_por_tienda
# Out:
#           Calificación
# Tienda
# Tienda 1      3.976685
# Tienda 2      4.037304
# Tienda 3      4.048326
# Tienda 4      3.995759

# %%
# Realizo un gráfico pandas
calificaciones_por_tienda.plot(kind='bar', xlabel='Tienda', ylabel='Calificación', title='Calificaciónes del Cliente por Tienda', figsize=(12, 8), color='sandybrown', legend=False, rot=False)
# Out:
# <Axes: title={'center': 'Calificaciónes del Cliente por Tienda'}, xlabel='Tienda', ylabel='Calificación'>

# %% [markdown]
# ## **COMPARATIVA DE COSTO PROMEDIO DE ENVÍOS REALIZADOS POR TIENDA**

# %%
# Genero un dataframe pandas de los valores promedio de los envíos
envios_por_tienda = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Costo de Envío': [tienda1_envio, tienda2_envio, tienda3_envio, tienda4_envio]
})

# %%
# Visualizo el dataframe
envios_por_tienda
# Out:
#      Tienda  Costo de Envío
# 0  Tienda 1    26018.609580
# 1  Tienda 2    25216.235693
# 2  Tienda 3    24805.680373
# 3  Tienda 4    23459.457167

# %%
# Formateo el índice del dataframe
envios_por_tienda.set_index('Tienda', inplace=True)

# %%
# Verifico el dataframe comparativo de costos de envío
envios_por_tienda
# Out:
#           Costo de Envío
# Tienda
# Tienda 1    26018.609580
# Tienda 2    25216.235693
# Tienda 3    24805.680373
# Tienda 4    23459.457167

# %%
# Genero un gráfico pandas
envios_por_tienda.plot(kind='bar', xlabel='Tienda', ylabel='Costo de Envío', title='Costo de Envío por Tienda', figsize=(12, 8), color='rosybrown', legend=False, rot=False)
# Out:
# <Axes: title={'center': 'Costo de Envío por Tienda'}, xlabel='Tienda', ylabel='Costo de Envío'>

# %% [markdown]
# # **INFORME FINAL**

# %% [markdown]
# En este análisis debíamos individualizar cuál de las 4 tiendas tenía el menor desempeño económico para el señor Juan, de manera de poder recomendarle la venta de la misma para que pudiera invertir ese dinero en su nuevo emprendimiento.
#
# En un **primer análisis** pudimos observar que la tienda 4 era la que menos ingresos generó en los últimos años.
#
# ![ventas_por_tienda_barras.png](data:image/png;base64,...)
#
# Para saber cuán importante es la proporción de ingresos de cada tienda para el señor Juan comparamos los ingresos como porcentajes del total de las cuatro tiendas.
#
# ![ventas_tiendas_proporcion.png](data:image/png;base64,...)
#
# Observamos que la tienda 4 es poco más del **23%** del total de ingresos.
#
# Al analizar las **categorías de productos** más y menos vendidas, como así también los **productos** más y menos vendidos no pudimos individualizar algún patrón o razón que explique la diferencia de ventas entre tiendas, deberíamos realizar algún otro análisis o identificar otra variable con la cual utilizar estos hallazgos para tener alguna conclusión significativa.
#
# Al comparar las **calificaciones del cliente** de las cuatro tiendas notamos que la calificación de la tienda 1 es levemente inferior a la de la tienda 4, la menor de las otras 3, por lo que no podemos inferir que la tienda 1 vaya a tener una disminución de sus ingresos en el futuro como para aventurarnos a recomendar la venta de la tienda 1.
#
# ![calificacion_del_cliente.png](data:image/png;base64,...)
#
# Sería necesario un análisis temporal de las ventas para ver el desempeño de las tiendas a lo largo del tiempo.
#
# Por último, analizamos el **promedio de los costos de envío** de los productos de cada tienda para ver si influyen en el desempeño de las ventas o también en la calificación que los clientes hacen de las mismas.
#
# ![costo_de_envio.png](data:image/png;base64,...)
#
# Observamos que el costo de envío, en promedio, resulta menor en la tienda 4, siendo el mayor en la tienda 1, seguido de las tiendas 2 y 3. No podemos inferir que los menores ingresos de la tienda 4 se deban a un mayor costo, todo lo contrario, podemos observar que las tiendas con mayores costos de envío son las que mayor desempeño tienen.
#
# Deberíamos hacer más análisis para encontrar la razón de ello, ya que las personas podrían elegir comprar en dichas tiendas sin importar el valor del envío por diferentes motivos como disponibilidad de productos en stock, entregas a tiempo, atención rápida, etc.
#
# Sin tener en cuenta una certera evaluación de proyección a futuro de ventas, al menos en primera instancia, la **tienda 4** es la menos productiva para el señor Juan. Deberíamos realizar análisis extras para poder recomendar la venta de la misma con una seguridad mucho mayor.
